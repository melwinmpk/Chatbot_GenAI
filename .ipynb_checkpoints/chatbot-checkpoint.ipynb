# %%
# !pip install streamlit pypdf2 langchain faiss-cpu
# Out:
# ...
#      ---------------------------------------- 9.1/9.1 MB 13.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 232.6/232.6 kB 14.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 12.8 MB/s eta 0:00:00
# ...
#      --------------------------------------- 13.8/13.8 MB 10.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 434.5/434.5 kB 13.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.2/98.2 kB 5.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 207.6/207.6 kB 12.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 242.4/242.4 kB 14.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 79.1/79.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 731.2/731.2 kB 15.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.9/6.9 MB 14.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 431.4/431.4 kB 13.6 MB/s eta 0:00:00
# ...

# %%
import streamlit as st 


st.header("My First Chatbot")

with st.sidebar:
    st.title("Your Documents")
    file = st.file_uploader("Upload a PDf file and start asking question", type="pdf")
# Out:
# 2025-01-16 13:13:51.789 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-16 13:13:52.143
# ...
#   command:
#
#     streamlit run D:\Learning\python-environment\ds\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-16 13:13:52.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-16 13:13:52.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-16 13:13:52.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-16 13:13:52.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-16 13:13:52.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
'''Melwin copy the above code in a python file
   run after activating the python environment 
   streamlit 
'''
